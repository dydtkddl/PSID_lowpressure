# %% [markdown]
# ## NOT VALID 폴더 삭제 트리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import shutil
from  pathlib import Path
ST_PATH =  Path("./try06_struct/")
SIR_PATH =  Path("./try06_struct+input_random/")
SIQ_PATH =  Path("./try06_struct+input_qt_then_rd/")
S_PATH = SIR_PATH
S_PATH = SIQ_PATH
import os 
S_DIRS = [x for x in os.listdir(S_PATH)  if os.path.isdir(S_PATH/x)]
S_DIRS
def isvalid(x):
    if x <= 1 :
        return 0 
    else:
        return 1
for S in S_DIRS:
    P = S_PATH /S/"trial_001"
    FLAG=  isvalid(len(os.listdir(P)))
    if FLAG == 1:
        print(1)
    else:
        shutil.rmtree(S_PATH/S)
        print("remove")
# Out:
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove
# remove

# %% [markdown]
# ## 성능 지표 크롭

# %%
import argparse 
import numpy as np 
import os 
import pandas as pd 
import logging
from pathlib import Path
from tqdm import tqdm

def process_dirname(dirname):
    SPL = dirname.split("_")
    GAS = SPL[0]
    TEMP = SPL[1]
    LOW = SPL[2]
    HIGH = SPL[4]
    INPUT = SPL[6]
    SAMPLING = "_".join(SPL[8:-2])
    MODEL = SPL[-1]
    return {
        "GAS": GAS,
        "TEMP": TEMP,
        "LOW": LOW,
        "HIGH": HIGH,
        "INPUT": INPUT,
        "SAMPLING": SAMPLING,
        "MODEL": MODEL,
    }

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--target_dir", default="./")
    parser.add_argument("--outcsv", default="METRICS_OUTPUT.csv")
    parser.add_argument("--n_trial", default=5)
    args = parser.parse_args()

    # logging 설정
    logging.basicConfig(
        level=logging.INFO,
        format="%(asctime)s [%(levelname)s] %(message)s"
    )

    S_PATH = Path(args.target_dir)
    N_TRIAL = int(args.n_trial)
    LIS = []

    # 상위 디렉토리 순회
    for P in tqdm([x for x in os.listdir(S_PATH) if os.path.isdir(S_PATH/x)], desc="Processing directories"):
        logging.info(f"Processing directory: {P}")
        DICT = process_dirname(P)

        TRIALS = [f"trial_{i:03d}" for i in range(1, N_TRIAL + 1)]
        R2_LIS, MAE_LIS = [], []

        for TRIAL in tqdm(TRIALS, desc=f"Trials for {P}", leave=False):
            T = TRIAL.replace("_", "")
            CSV = S_PATH / P / TRIAL / f"metrics_holdout_{T}.csv"
            if not CSV.exists():
                logging.warning(f"Missing file: {CSV}")
                continue

            df = pd.read_csv(CSV)
            R2 = df["R2"].values[0]
            MAE = df["MAE"].values[0]
            R2_LIS.append(R2)
            MAE_LIS.append(MAE)
            logging.info(f"[{P} | {TRIAL}] R2={R2:.4f}, MAE={MAE:.4f}")

        if R2_LIS:
            DICT["R2_MEAN"] = np.mean(R2_LIS)
            DICT["R2_STD"] = np.std(R2_LIS)
            DICT["MAE_MEAN"] = np.mean(MAE_LIS)
            DICT["MAE_STD"] = np.std(MAE_LIS)
            LIS.append(DICT)
            logging.info(f"[{P}] R2_MEAN={DICT['R2_MEAN']:.4f}, MAE_MEAN={DICT['MAE_MEAN']:.4f}")

    out_df = pd.DataFrame(LIS)
    out_df.to_csv(args.outcsv, index=False)
    logging.info(f"Saved results → {args.outcsv}")

if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--target_dir TARGET_DIR] [--outcsv OUTCSV]
#                              [--n_trial N_TRIAL]
# ipykernel_launcher.py: error: unrecognized arguments: --f=c:\Users\PSID_PC_20\AppData\Roaming\jupyter\runtime\kernel-v355312802c9a8d0c7b189a67181b21e69e1925338.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# c:\Users\PSID_PC_20\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
SPL = P.split("_")
GAS = SPL[0]
TEMP = SPL[1]
LOW = SPL[2]
HIGH = SPL[4]
INPUT = SPL[6]
SAMPLING = "_".join(SPL[8:-2])
MODEL = SPL[-1]
SAMPLING
# 'He',
#  '293',
#  'Henry',
#  'to',
#  '5',
#  '',
#  'struct',
#  '',
#  'random',
#  'struct',
#  '',
#  'rf']
# Out:
# 'random_struct'

# %%
[ x for x in os.listdir(S_PATH) if os.path.isdir(x)]
# Out:
# []

# %%
os.listdir(S_PATH)
# Out:
# ['He_293_Henry_to_15__struct__random_struct__cat',
#  'He_293_Henry_to_15__struct__random_struct__gbm',
#  'He_293_Henry_to_15__struct__random_struct__rf',
#  'He_293_Henry_to_1__struct__random_struct__cat',
#  'He_293_Henry_to_1__struct__random_struct__gbm',
#  'He_293_Henry_to_1__struct__random_struct__rf',
#  'He_293_Henry_to_5__struct__random_struct__cat',
#  'He_293_Henry_to_5__struct__random_struct__gbm',
#  'He_293_Henry_to_5__struct__random_struct__rf',
#  'run_commands.txt']
